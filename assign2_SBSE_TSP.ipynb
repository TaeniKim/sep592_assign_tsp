# %% [markdown]
# # SEP592 AI Based SE - Assign#2 TSP Solver

# %% [markdown]
# ## 1. Git 저장소에서 소스파일 및 Data 파일 Clone 받는다

# %%
# !git clone https://github.com/TaeniKim/sep592_assign_tsp.git
# Out:
# Cloning into 'sep592_assign_tsp'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 33 (delta 12), reused 19 (delta 1), pack-reused 0
# Unpacking objects: 100% (33/33), done.

# %% [markdown]
# ## 2. a280.tsp - greedy 실행

# %%
# !cd /content/sep592_assign_tsp/ && python tsp_solver.py a280.tsp
# Out:
# unique clusters of K-Means=
# [0]
#
# exec_all -- start..!!
# Start greedy all -- ratio: 0.1
# Exec_greedy start..!!
# Elapse:  0.03454089164733887
# Distance:  3278.071469986563
# total node and distance: 280 --> 3278.071469986563

# %% [markdown]
# ## 2. a280.tsp - ga 실행

# %% [markdown]
# ### default args - GA
# - population size = 10
# - generation limit = 10
# - selection elite rate = 0.2
# - selection tournement rate = 0.2
# - crossover size min = 10
# - crossover size max = 50
# - mutation rate = 0.2
# - mutation size min = 3
# - mutation size max = 10

# %%
# !cd /content/sep592_assign_tsp/ && python tsp_solver.py a280.tsp -a ga
# Out:
# Start greedy4init -- s:52, e:166
# Elapse Time:  0.03962826728820801
#
# Start greedy4init -- s:216, e:257
# Elapse Time:  0.03742790222167969
#
# Start greedy4init -- s:51, e:50
# Elapse Time:  0.03639364242553711
#
# Start greedy4init -- s:138, e:121
# Elapse Time:  0.03624105453491211
#
# Start greedy4init -- s:9, e:117
# Elapse Time:  0.0415501594543457
#
# Start greedy4init -- s:172, e:105
# Elapse Time:  0.04100203514099121
#
# Start greedy4init -- s:229, e:105
# Elapse Time:  0.03789544105529785
#
# Start greedy4init -- s:247, e:73
# Elapse Time:  0.037444114685058594
#
# Start greedy4init -- s:12, e:101
# Elapse Time:  0.03737664222717285
#
# Start greedy4init -- s:38, e:234
# Elapse Time:  0.03574633598327637
#
# save_population..!!
#
# gen = 1
#
# selection
#
# evaluation
# calc_population_dist Start
# 0 -- 2899.04
# 1 -- 3164.57
# 2 -- 3101.62
# 3 -- 2936.95
# 4 -- 2906.26
# 5 -- 2991.22
# 6 -- 2902.02
# 7 -- 2940.83
# 8 -- 2863.05
# 9 -- 3052.56
# ...

# %%
from IPython.display import Image
Image('/content/sep592_assign_tsp/result/2021-07-28 175129_plot_2863.png', width=800, height=400)

# %% [markdown]
# # 새 섹션

# %%
# !cd /content/sep592_assign_tsp/ && python tsp_solver.py rl11849.tsp -a ga
# Out:
# Start greedy4init -- s:2503, e:4794
# Elapse Time:  70.25480031967163
#
# Start greedy4init -- s:6110, e:4747
# Elapse Time:  70.16322469711304
#
# Start greedy4init -- s:5192, e:3158
# Elapse Time:  70.74708127975464
#
# Start greedy4init -- s:10910, e:5900
# Elapse Time:  70.55991387367249
#
# Start greedy4init -- s:6191, e:7727
# Elapse Time:  70.69747877120972
#
# Start greedy4init -- s:6161, e:6131
# Elapse Time:  71.19672513008118
#
# Start greedy4init -- s:7843, e:3270
# Elapse Time:  71.09920334815979
#
# Start greedy4init -- s:1262, e:3859
# Elapse Time:  70.76809597015381
#
# Start greedy4init -- s:6818, e:1353
# Elapse Time:  70.88183522224426
#
# Start greedy4init -- s:2513, e:5401
# Elapse Time:  71.04494142532349
#
# save_population..!!
#
# gen = 1
#
# selection
#
# evaluation
# calc_population_dist Start
# 0 -- 1122401.90
# 1 -- 1099530.47
# 2 -- 1110654.53
# 3 -- 1105979.58
# 4 -- 1091782.08
# 5 -- 1088275.77
# 6 -- 1113387.90
# 7 -- 1109732.79
# 8 -- 1105328.21
# ...
